# %%
import pandas as pd

# %%
data = pd.read_csv("case_time_series.csv")
#calculate frequnecy of values in DIA1 column
pd.to_numeric(data['smoking'], errors='coerce').astype('Int8')
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 322180    1
# 322181    1
# 322182    1
# 322183    1
# 322184    1
# Name: smoking, Length: 322185, dtype: Int8

# %%
required_cols = {'date', 'tmean', 'smoking'}
missing = required_cols - set(data.columns)
if not missing:
    print("All columns are present")
else:
    print(f"Missing columns: {', '.join(sorted(missing))}")
# Out:
# All columns are present
